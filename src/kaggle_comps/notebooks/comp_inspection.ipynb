# %%
import json
import pathlib

from IPython import display
import matplotlib.pyplot as plt
import pandas as pd
import yaml

# %%
with pathlib.Path('../config.yml').open('r') as in_stream:
    config = yaml.load(in_stream, Loader=yaml.CLoader)

# %% [markdown]
# ## helpers

# %%
class Competition:
    def __init__(self, root_path, base_heading_level=3):
        self.root_path = pathlib.Path(root_path).expanduser()
        self.files = {'description': self.root_path/'raw/description.json',
                      'leaderboard': self.root_path/'raw/publicleaderboarddata.zip',
                     }
    
    def description(self):
        with self.files['description'].open('r') as in_stream:
            return json.load(in_stream)
    
    def leaderboard(self):
        return pd.read_csv(self.files['leaderboard'])
    
    def _show_heading(self, content, rel_level=1):
        prefix = '#' * (self.base_heading_level - 1 + rel_level)
        display.display(display.Markdown(f'{prefix} {content}'))
    
    def _ipython_display_(self):
        description = self.description()
        leaderboard = self.leaderboard()
        self._show_heading(''.format(**description))
        
    
    
class CompetitionFinder:
    def __init__(self, root_path):
        self.root_path = pathlib.Path(root_path).expanduser()
    
    def keys(self):
        candidates = (c.name for c in self.root_path.iterdir())
        yield from (k
                    for k in candidates
                    if all(f.exists() for f in self[k].files.values()))
    
    def __getitem__(self, k):
        return Competition(self.root_path/k)

# %%
comps = CompetitionFinder(pathlib.Path(config['dat_root'])/'comps')
list(comps.keys())
# Out:
# ['mlsp-2013-birds',
#  'covid19-local-us-ca-forecasting-week-1',
#  'predict-who-is-more-influential-in-a-social-network',
#  'halite',
#  'google-quest-challenge',
#  'kobe-bryant-shot-selection',
#  'GiveMeSomeCredit',
#  'hpa-single-cell-image-classification',
#  'text-normalization-challenge-english-language',
#  'how-much-did-it-rain-ii',
#  'denoising-dirty-documents',
#  'tensorflow2-question-answering',
#  'icdar2013-gender-prediction-from-handwriting',
#  'springleaf-marketing-response',
#  'sberbank-russian-housing-market',
#  'imaterialist-challenge-fashion-2018',
#  'R',
#  'Raising-Money-to-Fund-an-Organizational-Mission',
#  'expedia-hotel-recommendations',
#  'dont-call-me-turkey',
#  'planet-understanding-the-amazon-from-space',
#  'yelp-restaurant-photo-classification',
#  'second-annual-data-science-bowl',
#  'ranzcr-clip-catheter-line-classification',
#  'nips-2017-defense-against-adversarial-attack',
#  'facebook-recruiting-iv-human-or-bot',
#  'emvic',
#  'airbnb-recruiting-new-user-bookings',
#  'rsna-intracranial-hemorrhage-detection',
#  'vinbigdata-chest-xray-abnormalities-detection',
#  'bluebook-for-bulldozers',
#  'genentech-flu-forecasting',
#  'plant-seedlings-classification',
#  'dogs-vs-cats',
#  'osic-pulmonary-fibrosis-progression',
#  'histopathologic-cancer-detection',
#  'march-machine-learning-mania-2016',
#  'rfcx-species-audio-detection',
#  'pakdd-cup-2014',
#  'google-cloud-ncaa-march-madness-2020-division-1-womens-tournament',
#  'hubmap-kidney-segmentation',
#  'jane-street-market-prediction',
#  'ultrasound-nerve-segmentation',
#  'tabular-playground-series-feb-2021',
#  'petfinder-adoption-prediction',
#  'youtube8m-2018',
#  'open-images-2019-object-detection',
#  'random-acts-of-pizza',
#  'facebook-recruiting-iii-keyword-extraction',
#  'jigsaw-multilingual-toxic-comment-classification',
#  'lshtc',
#  'predict-west-nile-virus',
#  'imaterialist-fashion-2020-fgvc7',
#  'google-smartphone-decimeter-challenge',
#  'the-seeclickfix-311-challenge',
#  'kuzushiji-recognition',
#  'data-science-bowl-2019',
#  'cvpr-2018-autonomous-driving',
#  'event-recommendation-engine-challenge',
#  'bike-sharing-demand',
#  'cause-effect-pairs',
#  'stayalert',
#  'imaterialist-fashion-2019-FGVC6',
#  'avito-duplicate-ads-detection',
#  'the-icml-2013-bird-challenge',
#  'icdm-2015-drawbridge-cross-device-connections',
#  'data-science-bowl-2018',
#  'inclusive-images-challenge',
#  'ciphertext-challenge-iii',
#  'quora-insincere-questions-classification',
#  'santas-stolen-sleigh',
#  'forest-cover-type-prediction',
#  'sf-crime',
#  'just-the-basics-the-after-party',
#  'plant-pathology-2021-fgvc8',
#  'open-images-instance-segmentation-rvc-2020',
#  'nfl-impact-detection',
#  'humpback-whale-identification',
#  'twitter-psychopathy-prediction',
#  'overfitting',
#  'AlgorithmicTradingChallenge',
#  'cdiscount-image-classification-challenge',
#  'text-normalization-challenge-russian-language',
#  'the-allen-ai-science-challenge',
#  'facial-keypoints-detection',
#  'galaxy-zoo-the-galaxy-challenge',
#  'deloitte-churn-prediction',
#  'siim-covid19-detection',
#  'cifar-10',
#  'afsis-soil-properties',
#  'loan-default-prediction',
#  'santa-gift-matching',
#  'data-science-london-scikit-learn',
#  'conway-s-reverse-game-of-life',
#  'getting-started',
#  'imaterialist-challenge-FGVC2017',
#  'hotel-id-2021-fgvc8',
#  'global-energy-forecasting-competition-2012-load-forecasting',
#  'malware-classification',
#  'draper-satellite-image-chronology',
#  'tourism1',
#  'ncaam-march-mania-2021-spread',
#  'siim-isic-melanoma-classification',
#  'kddcup2012-track2',
#  'commonlitreadabilityprize',
#  'customer-retention',
#  'nfl-big-data-bowl-2020',
#  'santas-uncertain-bags',
#  'hashcode-2021-oqr-extension',
#  'landmark-retrieval-challenge',
#  'SemiSupervisedFeatureLearning',
#  'tpu-getting-started',
#  'us-census-challenge',
#  'liverpool-ion-switching',
#  'walmart-recruiting-sales-in-stormy-weather',
#  'challenges-in-representation-learning-the-black-box-learning-challenge',
#  'inaturalist-challenge-at-fgvc-2017',
#  'iwildcam-2019-fgvc6',
#  'carvana-image-masking-challenge',
#  'rossmann-store-sales',
#  'favorita-grocery-sales-forecasting',
#  'instant-gratification',
#  'lyft-motion-prediction-autonomous-vehicles',
#  'datasciencebowl',
#  'kdd-cup-2013-author-paper-identification-challenge',
#  'predict-closed-questions-on-stack-overflow',
#  'open-images-2019-instance-segmentation',
#  'awic2012',
#  'kddcup2012-track1',
#  'bengaliai-cv19',
#  'GestureChallenge',
#  'cat-in-the-dat',
#  'covid19-global-forecasting-week-2',
#  'ClaimPredictionChallenge',
#  'multilabel-bird-species-classification-nips2013',
#  'expedia-personalized-sort',
#  'data-science-bowl-2017',
#  'accelerometer-biometric-competition',
#  'chess',
#  'msdchallenge',
#  'santa-workshop-tour-2019',
#  'cprod1',
#  'ncaaw-march-mania-2021-spread',
#  'instacart-market-basket-analysis',
#  'quickdraw-doodle-recognition',
#  'santa-2019-revenge-of-the-accountants',
#  'lish-moa',
#  'stanford-covid-vaccine',
#  'facebook-ii',
#  'coleridgeinitiative-show-us-the-data',
#  'two-sigma-financial-modeling',
#  'finding-elo',
#  'grupo-bimbo-inventory-demand',
#  'ciphertext-challenge-ii',
#  'cassava-leaf-disease-classification',
#  'prudential-life-insurance-assessment',
#  'pubg-finish-placement-prediction',
#  'birdsong-recognition',
#  'talkingdata-adtracking-fraud-detection',
#  'mastercard-data-cleansing-competition-finals',
#  'tabular-playground-series-jun-2021',
#  'plant-pathology-2020-fgvc7',
#  'seizure-detection',
#  'iwildcam-2020-fgvc7',
#  'm5-forecasting-uncertainty',
#  'spooky-author-identification',
#  'DarkWorlds',
#  'yelp-recsys-2013',
#  'icdar2013-stroke-recovery-from-offline-data',
#  'online-sales',
#  'intel-mobileodt-cervical-cancer-screening',
#  'm5-forecasting-accuracy',
#  'passenger-screening-algorithm-challenge',
#  'benchmark-bond-trade-price-challenge',
#  'diabetic-retinopathy-detection',
#  'bigquery-geotab-intersection-congestion',
#  'siim-acr-pneumothorax-segmentation',
#  'demand-forecasting-kernels-only',
#  'indoor-location-navigation',
#  'statoil-iceberg-classifier-challenge',
#  'wikichallenge',
#  'outbrain-click-prediction',
#  '3d-object-detection-for-autonomous-vehicles',
#  'walmart-recruiting-store-sales-forecasting',
#  'herbarium-2020-fgvc7',
#  'multi-modal-gesture-recognition',
#  'jigsaw-toxic-comment-classification-challenge',
#  'WhatDoYouKnow',
#  'tabular-playground-series-apr-2021',
#  '15-071x-the-analytics-edge-competition-spring-2015',
#  'dont-overfit-ii',
#  'DontGetKicked',
#  'dunnhumbychallenge',
#  'mercari-price-suggestion-challenge',
#  'freesound-audio-tagging-2019',
#  'bosch-production-line-performance',
#  'noaa-right-whale-recognition',
#  'hungry-geese',
#  'mens-machine-learning-competition-2019',
#  'traveling-santa-problem',
#  'flavours-of-physics-kernels-only',
#  'billion-word-imputation',
#  'abstraction-and-reasoning-challenge',
#  'avazu-ctr-prediction',
#  'socialNetwork',
#  'word2vec-nlp-tutorial',
#  'amazon-employee-access-challenge',
#  'avito-prohibited-content',
#  'covid19-global-forecasting-week-1',
#  'MusicHackathon',
#  'belkin-energy-disaggregation-competition',
#  'yelp-recruiting',
#  '15-071x-the-analytics-edge-spring-20152',
#  'contradictory-my-dear-watson',
#  'liberty-mutual-group-property-inspection-prediction',
#  'dsg-hackathon',
#  'the-icml-2013-whale-challenge-right-whale-redux',
#  'how-much-did-it-rain',
#  'telstra-recruiting-network',
#  'facebook-v-predicting-check-ins',
#  'yandex-personalized-web-search-challenge',
#  'GEF2012-wind-forecasting',
#  'imet-2020-fgvc7',
#  'riiid-test-answer-prediction',
#  'cervical-cancer-screening',
#  'RxVolumePrediction',
#  'trec-covid-information-retrieval',
#  'google-ai-open-images-visual-relationship-track',
#  'nips-2017-non-targeted-adversarial-attack',
#  'kkbox-churn-prediction-challenge',
#  'birdclef-2021',
#  '20-newsgroups-ciphertext-challenge',
#  'risky-business',
#  'web-traffic-time-series-forecasting',
#  'landmark-retrieval-2020',
#  'walmart-recruiting-trip-type-classification',
#  'jigsaw-unintended-bias-in-toxicity-classification',
#  'the-analytics-edge-mit-15-071x',
#  'bnp-paribas-cardif-claims-management',
#  'tweet-sentiment-extraction',
#  'open-images-object-detection-rvc-2020',
#  'mens-machine-learning-competition-2018',
#  'inaturalist-2019-fgvc6',
#  'youtube8m-2019',
#  'bioresponse',
#  'two-sigma-connect-rental-listing-inquiries',
#  'landmark-recognition-challenge',
#  'unimelb',
#  'womens-machine-learning-competition-2019',
#  'helping-santas-helpers',
#  'deepfake-detection-challenge',
#  'iwildcam2021-fgvc8',
#  'ncaaw-march-mania-2021',
#  'challenges-in-representation-learning-multi-modal-learning',
#  'google-football',
#  'detecting-insults-in-social-commentary',
#  'covid19-global-forecasting-week-4',
#  'stumbleupon',
#  'donorschoose-application-screening',
#  'traveling-santa-2018-prime-paths',
#  'tabular-playground-series-jan-2021',
#  'career-con-2019',
#  'crowdflower-search-relevance',
#  'competitive-data-science-predict-future-sales',
#  'covid19-global-forecasting-week-5',
#  'ncaam-march-mania-2021',
#  'seizure-prediction',
#  'the-winton-stock-market-challenge',
#  'generative-dog-images',
#  'packing-santas-sleigh',
#  'transfer-learning-on-stack-exchange-tags',
#  'airbus-ship-detection',
#  'street-view-getting-started-with-julia',
#  'cat-in-the-dat-ii',
#  'pkdd-15-predict-taxi-service-trajectory-i',
#  'pf2012-diabetes',
#  'google-ai-open-images-object-detection-track',
#  'titanic',
#  'two-sigma-financial-news',
#  'kkbox-music-recommendation-challenge',
#  'whats-cooking-kernels-only',
#  'march-machine-learning-mania-2015',
#  'shelter-animal-outcomes',
#  'twitter-personality-prediction',
#  'liberty-mutual-fire-peril',
#  'restaurant-revenue-prediction',
#  'tourism2',
#  'wise-2014',
#  'house-prices-advanced-regression-techniques',
#  'the-nature-conservancy-fisheries-monitoring',
#  'zillow-prize-1',
#  'santander-product-recommendation',
#  'inaturalist-2018',
#  'santa-2020',
#  'rock-paper-scissors',
#  'ghouls-goblins-and-ghosts-boo',
#  'reducing-commercial-aviation-fatalities',
#  'dog-breed-identification',
#  'acquire-valued-shoppers-challenge',
#  'noaa-fisheries-steller-sea-lion-population-count',
#  'axa-driver-telematics-analysis',
#  'gendered-pronoun-resolution',
#  'PhotoQualityPrediction',
#  'dato-native',
#  'nomad2018-predict-transparent-conductors',
#  'crowdflower-weather-twitter',
#  'asap-aes',
#  'connectomics',
#  'prostate-cancer-grade-assessment',
#  'shopee-product-matching',
#  'recruit-restaurant-visitor-forecasting',
#  'criteo-display-ad-challenge',
#  'learning-social-circles',
#  'pkdd-15-taxi-trip-time-prediction-ii',
#  'integer-sequence-learning',
#  'kdd-cup-2014-predicting-excitement-at-donors-choose',
#  'hashcode-drone-delivery',
#  'whale-categorization-playground',
#  'hivprogression',
#  'march-machine-learning-mania-2017',
#  'google-cloud-ncaa-march-madness-2020-division-1-mens-tournament',
#  'leaf-classification',
#  'halite-iv-playground-edition',
#  'alaska2-image-steganalysis',
#  'homesite-quote-conversion',
#  'tmdb-box-office-prediction',
#  'womens-machine-learning-competition-2018',
#  'landmark-recognition-2020',
#  'landmark-retrieval-2019',
#  'sentiment-analysis-on-movie-reviews',
#  'gan-getting-started',
#  'avito-context-ad-clicks',
#  'tensorflow-speech-recognition-challenge',
#  'coupon-purchase-prediction',
#  'open-images-2019-visual-relationship',
#  'santander-customer-satisfaction',
#  'vsb-power-line-fault-detection',
#  'whats-cooking',
#  'acm-sf-chapter-hackathon-big',
#  'predict-volcanic-eruptions-ingv-oe',
#  'hhp',
#  'connectx',
#  'seti-breakthrough-listen',
#  'flavours-of-physics',
#  'melbourne-university-seizure-prediction',
#  'conways-reverse-game-of-life-2020',
#  'imaterialist-challenge-furniture-2018',
#  'movie-review-sentiment-analysis-kernels-only',
#  'hack-reduce-dunnhumby-hackathon',
#  'trackml-particle-identification',
#  'informs2010',
#  'GestureChallenge2',
#  'RTA',
#  'WIC2011',
#  'mdm',
#  'nlp-getting-started',
#  'decoding-the-human-brain',
#  'random-number-grand-challenge',
#  'emc-data-science',
#  'challenges-in-representation-learning-facial-expression-recognition-challenge',
#  'rsna-str-pulmonary-embolism-detection',
#  'nips-2017-targeted-adversarial-attack',
#  'state-farm-distracted-driver-detection',
#  'msk-redefining-cancer-treatment',
#  'recognizing-faces-in-the-wild',
#  'rsna-pneumonia-detection-challenge',
#  'landmark-recognition-2019',
#  'talkingdata-mobile-user-demographics',
#  'machinery-tube-pricing',
#  'hashcode-photo-slideshow',
#  'invasive-species-monitoring',
#  'job-salary-prediction',
#  'nyc-taxi-trip-duration',
#  'grasp-and-lift-eeg-detection',
#  'Kannada-MNIST',
#  'whale-detection-challenge',
#  'bms-molecular-translation',
#  'dogs-vs-cats-redux-kernels-edition',
#  'flower-classification-with-tpus',
#  'inria-bci-challenge',
#  'deloitte-western-australia-rental-prices',
#  'painter-by-numbers',
#  'tabular-playground-series-mar-2021',
#  'ams-2014-solar-energy-prediction-contest',
#  'new-york-city-taxi-fare-prediction',
#  'aerial-cactus-identification',
#  'pycon-2015-tutorial-predict-closed-questions-on-stack-overflow',
#  'ga-customer-revenue-prediction',
#  'battlefin-s-big-data-combine-forecasting-challenge',
#  'tabular-playground-series-may-2021',
#  'pku-autonomous-driving',
#  'boston-data-festival-hackathon',
#  'march-machine-learning-mania-2014',
#  'herbarium-2021-fgvc8',
#  'costa-rican-household-poverty-prediction',
#  'youtube8m',
#  'forest-cover-type-kernels-only',
#  'just-the-basics-strata-2013',
#  'kdd-cup-2013-author-disambiguation',
#  'poker-rule-induction',
#  'covid19-global-forecasting-week-3',
#  'mlsp-2014-mri',
#  'tradeshift-text-classification',
#  'dstl-satellite-imagery-feature-detection',
#  'MerckActivity',
#  'tgs-salt-identification-challenge',
#  'freesound-audio-tagging',
#  'higgs-boson',
#  'allstate-claims-severity',
#  'imagenet-object-localization-challenge',
#  'see-click-predict-fix',
#  'acm-sf-chapter-hackathon-small',
#  'FacebookRecruiting',
#  'ChessRatings2',
#  'predicting-red-hat-business-value',
#  'trends-assessment-prediction']

# %%
comp = comps['R']

# %%
comp.description()
# Out:
# {'ref': 'R',
#  'tags': [],
#  'description': 'The aim of this competition is to develop a recommendation engine for R libraries (or packages). (R is opensource statistics software.)',
#  'id': 2454,
#  'title': 'R Package Recommendation Engine',
#  'url': 'https://www.kaggle.com/c/R',
#  'deadline': '2011-02-08T09:00:00',
#  'category': 'Featured',
#  'reward': '$150',
#  'organizationName': None,
#  'organizationRef': None,
#  'kernelCount': 0,
#  'teamCount': 57,
#  'userHasEntered': False,
#  'userRank': None,
#  'mergerDeadline': None,
#  'newEntrantDeadline': None,
#  'enabledDate': '2010-10-10T04:00:28',
#  'maxDailySubmissions': 2,
#  'maxTeamSize': None,
#  'evaluationMetric': 'Area Under Receiver Operating Characteristic Curve',
#  'awardsPoints': True,
#  'isKernelsSubmissionsOnly': False,
#  'submissionsDisabled': True}

# %%
comp.leaderboard()
# Out:
#     TeamId             TeamName       SubmissionDate    Score
# 0     1362          One Old Dog  2011-02-08 08:48:41  0.98790
# 1     2973        Record Me Men  2011-02-08 08:24:03  0.98639
# 2     1418              Machine  2011-02-07 16:31:39  0.98553
# 3     3247            libGUNDAM  2011-02-08 08:42:28  0.98492
# 4     2868        Jeremy Howard  2011-01-21 04:48:50  0.98327
# 5     1291                ivank  2010-10-20 18:43:40  0.98232
# 6     1558                  JAV  2010-12-20 02:59:44  0.98161
# 7     1282            UC Irvine  2010-10-23 07:51:55  0.97943
# 8     1448                teamD  2010-11-17 02:37:31  0.97868
# 9     2935               n0name  2011-01-22 08:06:12  0.97708
# 10    1294                pivot  2011-02-08 03:25:44  0.97576
# 11    2918                 YaTa  2011-02-07 18:27:55  0.97513
# 12    2982                  Jab  2011-02-06 18:24:56  0.97161
# 13    1281         Dirk Nachbar  2010-10-12 08:55:59  0.97144
# 14    2738                User1  2010-12-31 19:39:39  0.96873
# 15    2837  LouisDuclosGosselin  2011-01-04 11:12:55  0.96873
# 16    2740            Joederttt  2010-12-31 20:53:20  0.96850
# 17    1460              Jon Lee  2010-11-18 02:03:24  0.96746
# 18    1737         Data Harvest  2011-02-07 17:37:55  0.96015
# 19    1454               PedroM  2011-01-26 16:05:38  0.95761
# 20    1571               Joseph  2010-12-26 00:58:15  0.95479
# 21    1401               Seyhan  2011-01-19 10:27:23  0.95364
# 22    1542               Robert  2011-02-07 08:36:54  0.95225
# 23    1443              steffen  2011-01-16 11:51:54  0.95117
# 24    3187              dichika  2011-02-03 12:56:41  0.95045
# 25    2086                David  2011-01-20 06:11:14  0.94716
# 26    1442          RWeThereYet  2010-12-28 06:56:56  0.94460
# 27    2736                 Blar  2010-12-31 19:13:03  0.94313
# 28    1458               SFRank  2010-11-17 20:44:18  0.93968
# 29    1733               rotest  2010-12-07 22:27:06  0.93645
# 30    1993                test2  2010-12-07 22:33:15  0.93609
# 31    3259           Liren Wang  2011-01-31 12:48:45  0.93252
# 32    1287           bayesTrees  2010-10-11 21:10:35  0.92204
# 33    1392       Klemen Zalogar  2010-10-20 17:29:08  0.88955
# 34    1361    QualityExcellence  2010-10-18 00:55:42  0.87789
# 35    1391   Konrad Banachewicz  2010-11-18 13:52:18  0.84270
# 36    3369         Dylan Harper  2011-02-07 04:19:07  0.83556
# 37    1429              t.weter  2010-10-27 05:27:06  0.82830
# 38    3234      Issei Kurahashi  2011-01-29 13:13:31  0.82090
# 39    1450             yilindai  2010-11-05 05:33:30  0.80501
# 40    1261        GLM Benchmark  2010-12-11 00:16:00  0.80442
# 41    1559                dahua  2010-11-18 22:07:51  0.79598
# 42    2102           marc holes  2010-12-14 19:25:02  0.76756
# 43    1736               atest3  2011-02-08 05:44:35  0.76376
# 44    1745              DILSHAN  2010-12-27 10:23:13  0.74194
# 45    2386           Wijesinghe  2010-12-21 06:05:26  0.73478
# 46    2388            Dhanushka  2010-12-21 06:16:32  0.71629
# 47    1285         JustGuessing  2010-10-11 13:05:14  0.71210
# 48    3338                  Tim  2011-02-08 02:10:51  0.60018
# 49    1283    BrazilDataHackers  2010-10-10 23:25:41  0.52156
# 50    1583         stratometric  2010-11-23 17:51:24  0.51713
# 51    2952                Kesha  2011-01-10 09:57:33  0.50669
# 52    2920         StadeSchuldt  2011-01-06 23:32:54  0.47141
# 53    3248                 momo  2011-02-08 02:51:20  0.23106
# 54    3383                  Cat  2011-02-08 08:25:08  0.20110
# 55    3373                Peter  2011-02-08 04:02:37  0.01821
# 56    3371                Feack  2011-02-08 06:02:46  0.01681

# %%
f = comp.files['leaderboard']

import zipfile

with zipfile.ZipFile(f) as archive:
    print(dir(archive))
    print(archive.namelist())
# Out:
# ['NameToInfo', '_RealGetContents', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_allowZip64', '_comment', '_didModify', '_extract_member', '_filePassed', '_fileRefCnt', '_fpclose', '_lock', '_open_to_write', '_sanitize_windows_name', '_seekable', '_strict_timestamps', '_windows_illegal_name_trans_table', '_write_end_record', '_writecheck', '_writing', 'close', 'comment', 'compression', 'compresslevel', 'debug', 'extract', 'extractall', 'filelist', 'filename', 'fp', 'getinfo', 'infolist', 'mode', 'namelist', 'open', 'printdir', 'pwd', 'read', 'setpassword', 'start_dir', 'testzip', 'write', 'writestr']
# ['R-publicleaderboard.csv']

# %% [markdown]
# ## comp

# %%
comp_name = 'recursion-cellular-image-classification'

# %%
paths = {'dat_root': pathlib.Path(config['dat_root']).expanduser()/'comps'/comp_name}
paths['raw'] = paths['dat_root']/'raw'

# %% [markdown]
# ## Description

# %%
with paths['raw'].joinpath('description.json').open('r') as in_stream:
    description = json.load(in_stream)

# %%
description
# Out:
# {'ref': 'recursion-cellular-image-classification',
#  'tags': ['research', 'biology', 'image data', 'classification'],
#  'description': 'CellSignal: Disentangling biological signal from experimental noise in cellular images',
#  'id': 14420,
#  'title': 'Recursion Cellular Image Classification',
#  'url': 'https://www.kaggle.com/c/recursion-cellular-image-classification',
#  'deadline': '2019-09-26T23:59:00',
#  'category': 'Research',
#  'reward': '$13,000',
#  'organizationName': 'Recursion Pharmaceuticals',
#  'organizationRef': 'recursionpharma',
#  'kernelCount': 0,
#  'teamCount': 865,
#  'userHasEntered': False,
#  'userRank': None,
#  'mergerDeadline': '2019-07-22T23:59:00',
#  'newEntrantDeadline': '2019-09-19T23:59:00',
#  'enabledDate': '2019-06-27T19:46:50',
#  'maxDailySubmissions': 5,
#  'maxTeamSize': 5,
#  'evaluationMetric': 'Categorization Accuracy',
#  'awardsPoints': True,
#  'isKernelsSubmissionsOnly': False,
#  'submissionsDisabled': False}

# %% [markdown]
# ## leaderboard
